# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
#import plotly.figure_factory as ff



df_election = pd.read_csv('election_train.csv')
df_demograhics = pd.read_csv('demographics_train.csv')

#Converting the column value into column header for party as there are only two parties republic and democratic
df2 = df_election.pivot_table(index=['State','County','Year','Office'], columns='Party', values='Votes',aggfunc=np.sum)
df_election = pd.DataFrame(df2.to_records())

# %%
# Merging the two dataframes after removing the extra spaces and the word county from end and 
# also converting the join column values into same lower case. 
df_election['County'] = df_election['County'].apply(lambda x: (x.replace(' County','')).lower().strip())
df_states = pd.read_csv('States.csv')
df_states.columns= ['State_Name','Abbreviation']
df_demograhics['County'] = df_demograhics['County'].apply(lambda x: x.lower().strip())
df_election=  pd.merge(df_election,df_states,left_on='State',right_on='Abbreviation')
df_election.drop(['Abbreviation','State'],axis=1,inplace=True)
df_election.rename(columns={'State_Name':'State'},inplace=True)

df_combined = pd.merge(df_demograhics,df_election,left_on=['State','County'],right_on=['State','County'],how='inner')

# %%
# here we are dropping the rows which has zero values for all the three attributes i.e. Citizen Voting-Age Population,
# Democratic, Republican as we can't use them for analysis
indexs = df_combined[ (df_combined['Citizen Voting-Age Population'] == 0) & (df_combined['Democratic'] == 0)&(df_combined['Republican'] ==0)].index
df_combined.drop(indexs , inplace=True)

# %%
# Creating the new column named 'party' which has the value 1 if democratic party wins and value 0 if republic party wins.
df_combined['Party'] = df_combined.apply(lambda row: 1 if (row['Democratic']>row['Republican']) else 0, axis=1)

# %%
#calculating the mean of median income party wise
mean_medianIncome_democratic = df_combined[df_combined['Party']==1]['Median Household Income'].mean()
mean_medianIncome_republican = df_combined[df_combined['Party']==0]['Median Household Income'].mean()

print('mean_medianIncome_democratic:',mean_medianIncome_democratic)
print('mean_medianIncome_republican:',mean_medianIncome_republican)


# mean median income of demoractic is greater than mean median income of republic county

# here we are applying null hypothesis to check whether this has happen by chance or not.

# null hypothesis is mean median income of demoractic is equal to mean median income of republic county.
# alternate hypothesis is mean median income of demoractic is not equal to the mean median income of republic county.

[statistic,pvalue]=st.ttest_ind(df_combined[df_combined['Party']==1]['Median Household Income'] ,
             df_combined[df_combined['Party']==0]['Median Household Income'], axis=0, equal_var=False, nan_policy='omit')

#since this method returns two tailed value for p and we want only one tail value so dividing it by 2
print('P value for median income',pvalue)

print('statistics:',statistic)

# since the p value is less than significance level so we can reject the null hypothesis
# which means Median Household Income mean of demoratic is greater than republican not by chance.
# Out:
# mean_medianIncome_democratic: 53798.732307692306
# mean_medianIncome_republican: 48746.81954022989
# P value for median income 7.149437363182572e-08
# statistics: 5.479141589767388

# %%
mean_totalPopulation_democratic  = df_combined[df_combined['Party']==1]['Total Population'].mean()
mean_totalPopulation_republican  = df_combined[df_combined['Party']==0]['Total Population'].mean()

print('mean_totalPopulation_republican :',mean_totalPopulation_republican)
print('mean_totalPopulation_democratic :',mean_totalPopulation_democratic )

# null hypothesis is mean Total Population of demoractic is equal to mean Total Population of republic county.
# alternate hypothesis is mean Total Population of demoractic is not equal to the mean Total Population of republic county.

[statistic,pvalue]=st.ttest_ind(df_combined[df_combined['Party']==1]['Total Population'] ,
             df_combined[df_combined['Party']==0]['Total Population'], axis=0, equal_var=False, nan_policy='omit')

#since this method returns two tailed value for p and we want only one tail value so dividing it by 2
print('P value for mean totalPopulation :',pvalue)

print('statistics:',statistic)

# since the p value is less than significance level so we can reject the null hypothesis
# which means total population mean of demoratic is greater than republican not by chance.
# Out:
# mean_totalPopulation_republican : 53864.6724137931
# mean_totalPopulation_democratic : 300998.3169230769
# P value for mean totalPopulation : 2.0478717602973023e-14
# statistics: 8.004638577960957

# %%
#adding new columns which will have exact value of people under differnet category instead of percentage so that we can compare differnet
#county values.
df_combined['Population_under_Age_29'] = (df_combined['Percent Age 29 and Under']/100)*df_combined['Total Population']
df_combined['Population_Age_65_and_Older'] = (df_combined['Percent Age 65 and Older']/100)*df_combined['Total Population']

df_combined['Population_Black_not_Hispanic_or_Latino'] = (df_combined['Percent Black, not Hispanic or Latino']/100)*df_combined['Total Population']
df_combined['Population_White_not_Hispanic_or_Latino'] = (df_combined['Percent White, not Hispanic or Latino']/100)*df_combined['Total Population']
df_combined['Population_Hispanic_or_Latino'] = (df_combined['Percent Hispanic or Latino']/100)*df_combined['Total Population']

df_combined['Population_female'] = (df_combined['Percent Female']/100)*df_combined['Total Population']
df_combined['Population_male'] = df_combined['Total Population'] - df_combined['Population_female']

df_combined['Population_Less_than_High_School_Degree'] = (df_combined['Percent Less than High School Degree']/100)*df_combined['Total Population']
df_combined['Population_Less_than_Bachelor\'s Degree']= (df_combined['Percent Less than Bachelor\'s Degree']/100)*df_combined['Total Population']

# %%
# To find how much variable depend on each other.
df_combined.cov()
# Out:
#                                                  FIPS  Total Population  \
# FIPS                                     1.692525e+08     -4.894854e+08
# Total Population                        -4.894854e+08      1.017238e+11
# Citizen Voting-Age Population           -2.010182e+08      2.015224e+10
# Percent White, not Hispanic or Latino   -1.808505e+04     -1.882872e+06
# Percent Black, not Hispanic or Latino    5.998272e+03      7.233899e+05
# Percent Hispanic or Latino               2.403913e+04      7.716868e+05
# Percent Foreign Born                    -1.600538e+03      9.998648e+05
# Percent Female                          -1.158572e+02      1.160697e+05
# Percent Age 29 and Under                 4.978853e+03      3.310264e+05
# Percent Age 65 and Older                -5.003774e+03     -4.095582e+05
# Median Household Income                 -5.483202e+06      9.995766e+08
# Percent Unemployed                      -2.445059e+03      6.782100e+04
# Percent Less than High School Degree     1.799107e+04     -1.348611e+05
# Percent Less than Bachelor's Degree      6.856780e+03     -1.093833e+06
# Percent Rural                            3.112190e+04     -4.664961e+06
# Year                                     0.000000e+00      0.000000e+00
# Democratic                              -1.191584e+08      2.159578e+10
# Republican                              -9.151642e+07      1.308935e+10
# Population_under_Age_29                 -1.740586e+08      4.189645e+10
# Population_Age_65_and_Older             -9.393797e+07      1.292479e+10
# Population_Black_not_Hispanic_or_Latino -6.958764e+07      1.584320e+10
# Population_White_not_Hispanic_or_Latino -2.819534e+08      4.685647e+10
# Population_Hispanic_or_Latino           -9.328189e+07      2.879802e+10
# Population_female                       -2.522135e+08      5.186679e+10
# Population_male                         -2.372719e+08      4.985703e+10
# Population_Less_than_High_School_Degree -5.261450e+07      1.491326e+10
# Population_Less_than_Bachelor's Degree  -3.434626e+08      6.831660e+10
#
#                                          Citizen Voting-Age Population  \
# FIPS                                                     -2.010182e+08
# Total Population                                          2.015224e+10
# Citizen Voting-Age Population                             1.563511e+10
# Percent White, not Hispanic or Latino                    -3.154594e+05
# Percent Black, not Hispanic or Latino                     1.182935e+05
# Percent Hispanic or Latino                                1.047120e+05
# Percent Foreign Born                                      1.612893e+05
# Percent Female                                            2.916856e+04
# Percent Age 29 and Under                                  8.297414e+04
# Percent Age 65 and Older                                 -9.075577e+04
# Median Household Income                                   2.734869e+08
# Percent Unemployed                                        1.470411e+04
# Percent Less than High School Degree                     -6.174564e+04
# Percent Less than Bachelor's Degree                      -2.758778e+05
# Percent Rural                                            -1.117784e+06
# Year                                                      0.000000e+00
# Democratic                                                4.268708e+09
# Republican                                                3.179573e+09
# Population_under_Age_29                                   8.210476e+09
# Population_Age_65_and_Older                               2.845223e+09
# Population_Black_not_Hispanic_or_Latino                   1.940142e+09
# Population_White_not_Hispanic_or_Latino                   1.175209e+10
# Population_Hispanic_or_Latino                             4.566590e+09
# Population_female                                         1.026663e+10
# Population_male                                           9.885611e+09
# Population_Less_than_High_School_Degree                   2.371063e+09
# Population_Less_than_Bachelor's Degree                    1.342705e+10
#
#                                          Percent White, not Hispanic or Latino  \
# FIPS                                                             -1.808505e+04
# Total Population                                                 -1.882872e+06
# Citizen Voting-Age Population                                    -3.154594e+05
# Percent White, not Hispanic or Latino                             3.903253e+02
# Percent Black, not Hispanic or Latino                            -8.430253e+01
# Percent Hispanic or Latino                                       -2.459159e+02
# Percent Foreign Born                                             -7.816261e+01
# Percent Female                                                    4.662713e+00
# Percent Age 29 and Under                                         -5.088779e+01
# Percent Age 65 and Older                                          3.572607e+01
# Median Household Income                                           2.433536e+03
# Percent Unemployed                                               -1.359309e+01
# Percent Less than High School Degree                             -6.470277e+01
# Percent Less than Bachelor's Degree                               7.243777e+00
# Percent Rural                                                     2.364177e+02
# Year                                                              0.000000e+00
# Democratic                                                       -3.932863e+05
# Republican                                                       -1.880245e+05
# Population_under_Age_29                                          -7.978583e+05
# Population_Age_65_and_Older                                      -2.240011e+05
# Population_Black_not_Hispanic_or_Latino                          -3.845291e+05
# Population_White_not_Hispanic_or_Latino                          -5.945908e+05
# Population_Hispanic_or_Latino                                    -6.663157e+05
# Population_female                                                -9.614266e+05
# Population_male                                                  -9.214456e+05
# Population_Less_than_High_School_Degree                          -3.103633e+05
# Population_Less_than_Bachelor's Degree                           -1.280012e+06
#
#                                          Percent Black, not Hispanic or Latino  \
# FIPS                                                               5998.271643
# Total Population                                                 723389.860734
# Citizen Voting-Age Population                                    118293.519524
# Percent White, not Hispanic or Latino                               -84.302533
# Percent Black, not Hispanic or Latino                                86.315276
# Percent Hispanic or Latino                                           -1.171424
# Percent Foreign Born                                                 10.097591
# Percent Female                                                       -0.643152
# Percent Age 29 and Under                                              5.981190
# Percent Age 65 and Older                                             -8.474014
# Median Household Income                                            -491.876259
# Percent Unemployed                                                    7.028095
# Percent Less than High School Degree                                 10.688895
# Percent Less than Bachelor's Degree                                  -7.714457
# Percent Rural                                                       -72.596731
# Year                                                                  0.000000
# Democratic                                                       167781.094312
# Republican                                                        72724.732296
# Population_under_Age_29                                          298569.689359
# Population_Age_65_and_Older                                       90969.460252
# Population_Black_not_Hispanic_or_Latino                          236834.374542
# Population_White_not_Hispanic_or_Latino                          292633.581763
# Population_Hispanic_or_Latino                                    136791.939162
# Population_female                                                373458.065846
# Population_male                                                  349931.794888
# Population_Less_than_High_School_Degree                          106719.898781
# Population_Less_than_Bachelor's Degree                           495233.785335
#
#                                          Percent Hispanic or Latino  \
# FIPS                                                   24039.126011
# Total Population                                      771686.849728
# Citizen Voting-Age Population                         104711.980055
# Percent White, not Hispanic or Latino                   -245.915873
# Percent Black, not Hispanic or Latino                     -1.171424
# Percent Hispanic or Latino                               249.255440
# Percent Foreign Born                                      60.513526
# Percent Female                                            -4.791748
# Percent Age 29 and Under                                  33.963733
# Percent Age 65 and Older                                 -19.167929
# Median Household Income                                -9496.478156
# Percent Unemployed                                         2.429700
# Percent Less than High School Degree                      58.166088
# Percent Less than Bachelor's Degree                       12.237261
# Percent Rural                                           -131.200078
# Year                                                       0.000000
# Democratic                                            129608.167341
# Republican                                             74447.960565
# Population_under_Age_29                               340893.939096
# Population_Age_65_and_Older                            85007.391830
# Population_Black_not_Hispanic_or_Latino               103701.803038
# Population_White_not_Hispanic_or_Latino               142186.167404
# Population_Hispanic_or_Latino                         462243.695229
# Population_female                                     391214.463362
# Population_male                                       380472.386367
# Population_Less_than_High_School_Degree               158736.478161
# Population_Less_than_Bachelor's Degree                547623.864759
#
#                                          Percent Foreign Born  Percent Female  \
# FIPS                                             -1600.537699     -115.857161
# Total Population                                999864.759180   116069.741605
# Citizen Voting-Age Population                   161289.300663    29168.560184
# Percent White, not Hispanic or Latino              -78.162608        4.662713
# Percent Black, not Hispanic or Latino               10.097591       -0.643152
# Percent Hispanic or Latino                          60.513526       -4.791748
# Percent Foreign Born                                36.786298        0.121490
# Percent Female                                       0.121490        5.660549
# Percent Age 29 and Under                            12.461679        0.481307
# Percent Age 65 and Older                           -10.658047        0.937800
# Median Household Income                          22323.994359     3048.057912
# Percent Unemployed                                   0.644867        0.212392
# Percent Less than High School Degree                12.088464       -3.802885
# Percent Less than Bachelor's Degree                -18.560885       -6.078529
# Percent Rural                                      -98.038609      -15.540523
# Year                                                 0.000000        0.000000
# Democratic                                      222314.901061    27791.032551
# Republican                                      117091.947451    17795.061043
# Population_under_Age_29                         405957.649644    45358.291815
# Population_Age_65_and_Older                     128208.893837    17552.087388
# Population_Black_not_Hispanic_or_Latino         158350.784045    19406.382581
# Population_White_not_Hispanic_or_Latino         402802.257765    68767.808378
# Population_Hispanic_or_Latino                   316079.426985    18833.982003
# Population_female                               510805.466415    60704.458909
# Population_male                                 489059.292765    55365.282696
# Population_Less_than_High_School_Degree         150830.556435    13745.193501
# Population_Less_than_Bachelor's Degree          650353.216369    77220.316618
#
#                                          Percent Age 29 and Under  \
# FIPS                                                  4978.852689
# Total Population                                    331026.430955
# Citizen Voting-Age Population                        82974.141493
# Percent White, not Hispanic or Latino                  -50.887788
# Percent Black, not Hispanic or Latino                    5.981190
# Percent Hispanic or Latino                              33.963733
# Percent Foreign Born                                    12.461679
# Percent Female                                           0.481307
# Percent Age 29 and Under                                31.617033
# Percent Age 65 and Older                               -21.981707
# Median Household Income                              10124.424948
# Percent Unemployed                                       0.555987
# Percent Less than High School Degree                     6.207095
# Percent Less than Bachelor's Degree                    -11.080756
# Percent Rural                                          -90.853902
# Year                                                     0.000000
# Democratic                                           64614.939645
# Republican                                           39390.727723
# Population_under_Age_29                             156484.921978
# Population_Age_65_and_Older                          29737.100618
# Population_Black_not_Hispanic_or_Latino              51171.244771
# Population_White_not_Hispanic_or_Latino             155954.326616
# Population_Hispanic_or_Latino                        92120.177616
# Population_female                                   167678.214101
# Population_male                                     163348.216853
# Population_Less_than_High_School_Degree              48035.942374
# Population_Less_than_Bachelor's Degree              222300.322906
#
#                                          Percent Age 65 and Older  ...  \
# FIPS                                                 -5003.773851  ...
# Total Population                                   -409558.185526  ...
# Citizen Voting-Age Population                       -90755.765520  ...
# Percent White, not Hispanic or Latino                   35.726067  ...
# Percent Black, not Hispanic or Latino                   -8.474014  ...
# Percent Hispanic or Latino                             -19.167929  ...
# Percent Foreign Born                                   -10.658047  ...
# Percent Female                                           0.937800  ...
# Percent Age 29 and Under                               -21.981707  ...
# Percent Age 65 and Older                                22.655590  ...
# Median Household Income                             -20715.151425  ...
# Percent Unemployed                                      -0.277368  ...
# Percent Less than High School Degree                    -2.973298  ...
# Percent Less than Bachelor's Degree                     10.944258  ...
# Percent Rural                                           80.335866  ...
# Year                                                     0.000000  ...
# Democratic                                          -87889.186866  ...
# Republican                                          -51717.354737  ...
# Population_under_Age_29                            -180714.054535  ...
# Population_Age_65_and_Older                         -39975.860429  ...
# Population_Black_not_Hispanic_or_Latino             -62837.514022  ...
# Population_White_not_Hispanic_or_Latino            -207051.245993  ...
# Population_Hispanic_or_Latino                       -97802.960833  ...
# Population_female                                  -207578.384549  ...
# Population_male                                    -201979.800977  ...
# Population_Less_than_High_School_Degree             -54305.487219  ...
# Population_Less_than_Bachelor's Degree             -267715.560402  ...
#
#                                            Republican  \
# FIPS                                    -9.151642e+07
# Total Population                         1.308935e+10
# Citizen Voting-Age Population            3.179573e+09
# Percent White, not Hispanic or Latino   -1.880245e+05
# Percent Black, not Hispanic or Latino    7.272473e+04
# Percent Hispanic or Latino               7.444796e+04
# Percent Foreign Born                     1.170919e+05
# Percent Female                           1.779506e+04
# Percent Age 29 and Under                 3.939073e+04
# Percent Age 65 and Older                -5.171735e+04
# Median Household Income                  1.782099e+08
# Percent Unemployed                       7.109836e+03
# Percent Less than High School Degree    -3.989816e+04
# Percent Less than Bachelor's Degree     -1.733572e+05
# Percent Rural                           -6.994827e+05
# Year                                     0.000000e+00
# Democratic                               2.929408e+09
# Republican                               2.048512e+09
# Population_under_Age_29                  5.338111e+09
# Population_Age_65_and_Older              1.727982e+09
# Population_Black_not_Hispanic_or_Latino  1.675191e+09
# Population_White_not_Hispanic_or_Latino  6.823253e+09
# Population_Hispanic_or_Latino            3.427015e+09
# Population_female                        6.663528e+09
# Population_male                          6.425825e+09
# Population_Less_than_High_School_Degree  1.737742e+09
# Population_Less_than_Bachelor's Degree   8.705643e+09
#
#                                          Population_under_Age_29  \
# FIPS                                               -1.740586e+08
# Total Population                                    4.189645e+10
# Citizen Voting-Age Population                       8.210476e+09
# Percent White, not Hispanic or Latino              -7.978583e+05
# Percent Black, not Hispanic or Latino               2.985697e+05
# Percent Hispanic or Latino                          3.408939e+05
# Percent Foreign Born                                4.059576e+05
# Percent Female                                      4.535829e+04
# Percent Age 29 and Under                            1.564849e+05
# Percent Age 65 and Older                           -1.807141e+05
# Median Household Income                             3.931179e+08
# Percent Unemployed                                  2.606387e+04
# Percent Less than High School Degree               -4.598032e+04
# Percent Less than Bachelor's Degree                -4.398675e+05
# Percent Rural                                      -1.888366e+06
# Year                                                0.000000e+00
# Democratic                                          8.784500e+09
# Republican                                          5.338111e+09
# Population_under_Age_29                             1.740220e+10
# Population_Age_65_and_Older                         5.220370e+09
# Population_Black_not_Hispanic_or_Latino             6.574485e+09
# Population_White_not_Hispanic_or_Latino             1.904354e+10
# Population_Hispanic_or_Latino                       1.210376e+10
# Population_female                                   2.134979e+10
# Population_male                                     2.054666e+10
# Population_Less_than_High_School_Degree             6.232807e+09
# Population_Less_than_Bachelor's Degree              2.819583e+10
#
#                                          Population_Age_65_and_Older  \
# FIPS                                                   -9.393797e+07
# Total Population                                        1.292479e+10
# Citizen Voting-Age Population                           2.845223e+09
# Percent White, not Hispanic or Latino                  -2.240011e+05
# Percent Black, not Hispanic or Latino                   9.096946e+04
# Percent Hispanic or Latino                              8.500739e+04
# Percent Foreign Born                                    1.282089e+05
# Percent Female                                          1.755209e+04
# Percent Age 29 and Under                                2.973710e+04
# Percent Age 65 and Older                               -3.997586e+04
# Median Household Income                                 1.257700e+08
# Percent Unemployed                                      1.164914e+04
# Percent Less than High School Degree                   -2.372350e+04
# Percent Less than Bachelor's Degree                    -1.438646e+05
# Percent Rural                                          -6.373776e+05
# Year                                                    0.000000e+00
# Democratic                                              2.793737e+09
# Republican                                              1.727982e+09
# Population_under_Age_29                                 5.220370e+09
# Population_Age_65_and_Older                             1.743530e+09
# Population_Black_not_Hispanic_or_Latino                 1.944968e+09
# Population_White_not_Hispanic_or_Latino                 6.213832e+09
# Population_Hispanic_or_Latino                           3.482354e+09
# Population_female                                       6.600813e+09
# Population_male                                         6.323981e+09
# Population_Less_than_High_School_Degree                 1.826528e+09
# Population_Less_than_Bachelor's Degree                  8.695722e+09
#
#                                          Population_Black_not_Hispanic_or_Latino  \
# FIPS                                                               -6.958764e+07
# Total Population                                                    1.584320e+10
# Citizen Voting-Age Population                                       1.940142e+09
# Percent White, not Hispanic or Latino                              -3.845291e+05
# Percent Black, not Hispanic or Latino                               2.368344e+05
# Percent Hispanic or Latino                                          1.037018e+05
# Percent Foreign Born                                                1.583508e+05
# Percent Female                                                      1.940638e+04
# Percent Age 29 and Under                                            5.117124e+04
# Percent Age 65 and Older                                           -6.283751e+04
# Median Household Income                                             8.893158e+07
# Percent Unemployed                                                  1.919264e+04
# Percent Less than High School Degree                                2.057641e+03
# Percent Less than Bachelor's Degree                                -1.343021e+05
# Percent Rural                                                      -6.615875e+05
# Year                                                                0.000000e+00
# Democratic                                                          3.342760e+09
# Republican                                                          1.675191e+09
# Population_under_Age_29                                             6.574485e+09
# Population_Age_65_and_Older                                         1.944968e+09
# Population_Black_not_Hispanic_or_Latino                             3.708468e+09
# Population_White_not_Hispanic_or_Latino                             6.316983e+09
# Population_Hispanic_or_Latino                                       4.338312e+09
# Population_female                                                   8.128919e+09
# Population_male                                                     7.714279e+09
# Population_Less_than_High_School_Degree                             2.543549e+09
# Population_Less_than_Bachelor's Degree                              1.084453e+10
#
#                                          Population_White_not_Hispanic_or_Latino  \
# FIPS                                                               -2.819534e+08
# Total Population                                                    4.685647e+10
# Citizen Voting-Age Population                                       1.175209e+10
# Percent White, not Hispanic or Latino                              -5.945908e+05
# Percent Black, not Hispanic or Latino                               2.926336e+05
# Percent Hispanic or Latino                                          1.421862e+05
# Percent Foreign Born                                                4.028023e+05
# Percent Female                                                      6.876781e+04
# Percent Age 29 and Under                                            1.559543e+05
# Percent Age 65 and Older                                           -2.070512e+05
# Median Household Income                                             6.468923e+08
# Percent Unemployed                                                  2.832319e+04
# Percent Less than High School Degree                               -1.641866e+05
# Percent Less than Bachelor's Degree                                -6.653600e+05
# Percent Rural                                                      -2.610877e+06
# Year                                                                0.000000e+00
# Democratic                                                          1.058917e+10
# Republican                                                          6.823253e+09
# Population_under_Age_29                                             1.904354e+10
# Population_Age_65_and_Older                                         6.213832e+09
# Population_Black_not_Hispanic_or_Latino                             6.316983e+09
# Population_White_not_Hispanic_or_Latino                             2.552310e+10
# Population_Hispanic_or_Latino                                       1.054007e+10
# Population_female                                                   2.389078e+10
# Population_male                                                     2.296569e+10
# Population_Less_than_High_School_Degree                             6.033264e+09
# Population_Less_than_Bachelor's Degree                              3.087307e+10
#
#                                          Population_Hispanic_or_Latino  \
# FIPS                                                     -9.328189e+07
# Total Population                                          2.879802e+10
# Citizen Voting-Age Population                             4.566590e+09
# Percent White, not Hispanic or Latino                    -6.663157e+05
# Percent Black, not Hispanic or Latino                     1.367919e+05
# Percent Hispanic or Latino                                4.622437e+05
# Percent Foreign Born                                      3.160794e+05
# Percent Female                                            1.883398e+04
# Percent Age 29 and Under                                  9.212018e+04
# Percent Age 65 and Older                                 -9.780296e+04
# Median Household Income                                   1.327074e+08
# Percent Unemployed                                        1.553461e+04
# Percent Less than High School Degree                      4.091749e+04
# Percent Less than Bachelor's Degree                      -1.739782e+05
# Percent Rural                                            -9.581370e+05
# Year                                                      0.000000e+00
# Democratic                                                5.423582e+09
# Republican                                                3.427015e+09
# Population_under_Age_29                                   1.210376e+10
# Population_Age_65_and_Older                               3.482354e+09
# Population_Black_not_Hispanic_or_Latino                   4.338312e+09
# Population_White_not_Hispanic_or_Latino                   1.054007e+10
# Population_Hispanic_or_Latino                             1.139443e+10
# Population_female                                         1.464254e+10
# Population_male                                           1.415547e+10
# Population_Less_than_High_School_Degree                   4.876395e+09
# Population_Less_than_Bachelor's Degree                    1.994210e+10
#
#                                          Population_female  Population_male  \
# FIPS                                         -2.522135e+08    -2.372719e+08
# Total Population                              5.186679e+10     4.985703e+10
# Citizen Voting-Age Population                 1.026663e+10     9.885611e+09
# Percent White, not Hispanic or Latino        -9.614266e+05    -9.214456e+05
# Percent Black, not Hispanic or Latino         3.734581e+05     3.499318e+05
# Percent Hispanic or Latino                    3.912145e+05     3.804724e+05
# Percent Foreign Born                          5.108055e+05     4.890593e+05
# Percent Female                                6.070446e+04     5.536528e+04
# Percent Age 29 and Under                      1.676782e+05     1.633482e+05
# Percent Age 65 and Older                     -2.075784e+05    -2.019798e+05
# Median Household Income                       5.080967e+08     4.914799e+08
# Percent Unemployed                            3.502786e+04     3.279314e+04
# Percent Less than High School Degree         -6.905377e+04    -6.580736e+04
# Percent Less than Bachelor's Degree          -5.591493e+05    -5.346832e+05
# Percent Rural                                -2.382892e+06    -2.282069e+06
# Year                                          0.000000e+00     0.000000e+00
# Democratic                                    1.102590e+10     1.056988e+10
# Republican                                    6.663528e+09     6.425825e+09
# Population_under_Age_29                       2.134979e+10     2.054666e+10
# Population_Age_65_and_Older                   6.600813e+09     6.323981e+09
# Population_Black_not_Hispanic_or_Latino       8.128919e+09     7.714279e+09
# Population_White_not_Hispanic_or_Latino       2.389078e+10     2.296569e+10
# Population_Hispanic_or_Latino                 1.464254e+10     1.415547e+10
# Population_female                             2.645270e+10     2.541409e+10
# Population_male                               2.541409e+10     2.444293e+10
# Population_Less_than_High_School_Degree       7.604318e+09     7.308946e+09
# Population_Less_than_Bachelor's Degree        3.483268e+10     3.348392e+10
#
#                                          Population_Less_than_High_School_Degree  \
# FIPS                                                               -5.261450e+07
# Total Population                                                    1.491326e+10
# Citizen Voting-Age Population                                       2.371063e+09
# Percent White, not Hispanic or Latino                              -3.103633e+05
# Percent Black, not Hispanic or Latino                               1.067199e+05
# Percent Hispanic or Latino                                          1.587365e+05
# Percent Foreign Born                                                1.508306e+05
# Percent Female                                                      1.374519e+04
# Percent Age 29 and Under                                            4.803594e+04
# Percent Age 65 and Older                                           -5.430549e+04
# Median Household Income                                             7.873314e+07
# Percent Unemployed                                                  1.294638e+04
# Percent Less than High School Degree                                1.290707e+04
# Percent Less than Bachelor's Degree                                -1.047758e+05
# Percent Rural                                                      -5.723043e+05
# Year                                                                0.000000e+00
# Democratic                                                          2.939178e+09
# Republican                                                          1.737742e+09
# Population_under_Age_29                                             6.232807e+09
# Population_Age_65_and_Older                                         1.826528e+09
# Population_Black_not_Hispanic_or_Latino                             2.543549e+09
# Population_White_not_Hispanic_or_Latino                             6.033264e+09
# Population_Hispanic_or_Latino                                       4.876395e+09
# Population_female                                                   7.604318e+09
# Population_male                                                     7.308946e+09
# Population_Less_than_High_School_Degree                             2.448146e+09
# Population_Less_than_Bachelor's Degree                              1.025034e+10
#
#                                          Population_Less_than_Bachelor's Degree
# FIPS                                                              -3.434626e+08
# Total Population                                                   6.831660e+10
# Citizen Voting-Age Population                                      1.342705e+10
# Percent White, not Hispanic or Latino                             -1.280012e+06
# Percent Black, not Hispanic or Latino                              4.952338e+05
# Percent Hispanic or Latino                                         5.476239e+05
# Percent Foreign Born                                               6.503532e+05
# Percent Female                                                     7.722032e+04
# Percent Age 29 and Under                                           2.223003e+05
# Percent Age 65 and Older                                          -2.677156e+05
# Median Household Income                                            5.532476e+08
# Percent Unemployed                                                 5.689078e+04
# Percent Less than High School Degree                              -6.388075e+04
# Percent Less than Bachelor's Degree                               -6.359056e+05
# Percent Rural                                                     -3.098923e+06
# Year                                                               0.000000e+00
# Democratic                                                         1.406389e+10
# Republican                                                         8.705643e+09
# Population_under_Age_29                                            2.819583e+10
# Population_Age_65_and_Older                                        8.695722e+09
# Population_Black_not_Hispanic_or_Latino                            1.084453e+10
# Population_White_not_Hispanic_or_Latino                            3.087307e+10
# Population_Hispanic_or_Latino                                      1.994210e+10
# Population_female                                                  3.483268e+10
# Population_male                                                    3.348392e+10
# Population_Less_than_High_School_Degree                            1.025034e+10
# Population_Less_than_Bachelor's Degree                             4.655839e+10
#
# [27 rows x 27 columns]

# %%
df_combined.groupby("Party")['Population_under_Age_29'].mean().plot(kind='bar',color=["r","b"],title="Population_under_Age_29")

# %%
df_combined.groupby("Party")['Total Population'].sum().plot(kind='bar',color=["r","b"],title="Total Population")

# %%
df_combined.groupby("Party")['Population_Age_65_and_Older'].mean().plot(kind='bar',color=["r","b"],title="Population_Age_65_and_Older")

# %%
df_combined.groupby("Party")['Population_Black_not_Hispanic_or_Latino'].mean().plot(kind='bar',color=["r","b"],title="Population_Black_not_Hispanic_or_Latino")

# %%
df_combined.groupby("Party")['Population_White_not_Hispanic_or_Latino'].mean().plot(kind='bar',color=["r","b"],title="Population_White_not_Hispanic_or_Latino")

# %%
df_combined.groupby("Party")['Population_Hispanic_or_Latino'].mean().plot(kind='bar',color=["r","b"],title="Population_Hispanic_or_Latino")

# %%
df_combined.groupby("Party")['Population_female'].mean().plot(kind='bar',color=["r","b"],title=" Female Population")

# %%
df_combined.groupby("Party")['Population_Less_than_High_School_Degree'].mean().plot(kind='bar',color=["r","b"],title="Population_Less_than_High_School_Degree")

# %%
df_combined.groupby("Party")['Population_Less_than_Bachelor\'s Degree'].mean().plot(kind='bar',color=["r","b"],title="Population less than bachelor Degree")

# %%
df_combined.groupby("Party")['Population_male'].mean().plot(kind='bar',color=["r","b"],title=" Male Population")
